# %%
x,y,z="orange","Banana","Cheery"
print(x)
print(y)
print(z)
# Out:
# orange
# Banana
# Cheery

# %%
x=y=z="Khushboo"
print(x)
print(y)
print(z)

x=10
def printq():
    x=5
    print(x)
printq()
# Out:
# Khushboo
# Khushboo
# Khushboo
# 5

# %%
x="python"
x=10
print(x)
# Out:
# 10

# %%
#unpacked collection
fruits=["apple","banana"]
x,y=fruits
print(x)
print(y)
# Out:
# apple
# banana

# %%
x="Super"
def myFunc():
    print(f"Python is {x}")
myFunc()
# Out:
# Python is Super

# %%
#variables
x=10
print(type(x))
# Out:
# <class 'int'>

# %%
#Python Type_Casting 

x=int(1)
y=int(10.20)
z=str("rahul")
print(x)
print(y)
print(z)
# Out:
# 1
# 10
# rahul

# %%
x=str("11")
y=str(2)
z=str(10.0)
print(x)
print(y)
print(z)
print(type(z))
# Out:
# 11
# 2
# 10.0
# <class 'str'>

# %%
x="String1","String2","String3"
print(x)
# Out:
# ('String1', 'String2', 'String3')

# %%
a="Hi my name is Khushboo Giri, and i am currently pursuing B.tech from bbditm"
print(a)
# Out:
# Hi my name is Khushboo Giri, and i am currently pursuing B.tech from bbditm

# %%
b="Hello,World"
print(b[8:])
print(b[-3:])
print(b[:5])
# Out:
# rld
# rld
# Hello

# %%
a="Hello,world"
print(a.upper())
# Out:
# HELLO,WORLD

# %%
x=10
y=18
z=6
d=x+y*z
print(d)
c=x&z|y
print(c)
print(x)
print(y)
print(z)
# Out:
# 118
# 18
# 10
# 18
# 6

# %%
x=25
x//=4
print(x)
# Out:
# 6

# %%
a=6
a**=2
a+=4
print(a)
# Out:
# 40

# %%
balance=10000
balance+=5000
balance-=3000
balance*=2
print(balance)
# Out:
# 24000

# %%
x=20
y=7
x+=y
y+=x
print(x,y)
# Out:
# 27 34

# %%
a=20
b=10
print(a!=b)
# Out:
# True

# %%
a=20
a-=10
a*=3
a//=4
print(a)
# Out:
# 7

# %%
temp=30
print(temp<35)
# Out:
# True

# %%
x=20
y=15
print(x>y)
print(x<y)
print(x==y)
# Out:
# True
# False
# False

# %%
#Logical oprator
age=20
has_license =True
print(age>= 18 and has_license)
# Out:
# True

# %%
#identity operator
a=[1,2,3]
b=[1,2,3]
print(a==b)
print(b==a)
# Out:
# True
# True

# %%
#membership operator
fruits=['apple','orange','mango']
print("apple" in fruits)
# Out:
# True

# %%
a=10
b=6
print(a&b)
print(a|b)
# Out:
# 2
# 14

# %%
#Left Shift 
a=5
print(a<<1)
print(a<<2)
#Right shift
x=5
print(x>>1)
print(x>>2)
# Out:
# 10
# 20
# 2
# 1
