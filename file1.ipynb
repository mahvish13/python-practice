# %%
for i in range(0,6):
   for j in range(i):
     print("*" ,end="")
   print()
# Out:
# *
# **
# ***
# ****
# *****

# %%
for i in range(0,6):
   for j in range(0,6):
     print("*" ,end="")
   print()
# Out:
# ******
# ******
# ******
# ******
# ******
# ******

# %%
f=open("file2.txt","w")
f.write("Hello")
f.close()
with open("file2.txt","w") as f:
    f.write("how are you?\n")
    f.write("hey guys\n")
    f.write("i am a python developer\n")
    
    a=["hi khushboo\n","hey mahvish i am a software developer\n","i can do anything\n"]
    f.writelines(a)
f.close()
f=open("file2.txt","r")

con=f.read()
print(con)
f.close()
# Out:
# how are you?
# hey guys
# i am a python developer
# hi khushboo
# hey mahvish i am a software developer
# i can do anything

# %%
with open("file2.txt","a") as f:
    f.write("We are adding new content.\n")

# %%
with open ("file2.txt","r") as f:
    f.read(10)
    print(f.tell())
f.close()
# Out:
# 10

# %%
try:
    numerator=float(input("Enter first the value:"))
    denominator=float(input("Enter Second the value:"))
    result=numerator/denominator
    print(f"Result:(result)")
except ZeroDivisionError:
    print("Error can't devide by zero")
except ValueError:
    print("there is value error")
